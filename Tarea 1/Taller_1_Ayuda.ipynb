# %% [markdown]
# <h1 align='center'> INF-280 Estadística Computacional 2023-1 </h1>
#
# <H3 align='center'> Funciones y métodos para el Taller 1 </H3>

# %% [markdown]
# ### Importar librerías

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Lectura de Archivo

# %%
df = pd.read_csv("https://drive.google.com/uc?id=1c2HowCraYTESP4O_llI9JP46iAUCP1LN")
df
# Out:
#       index  edad      genero         region    zona cambio_climatico  \
# 0         0    21   Masculino       Los rios  Urbana             Alta
# 1         1    61   Masculino          Maule  Urbana            Media
# 2         2    22  No Binario  Metropolitana  Urbana         Muy Alta
# 3         3    21   Masculino          Aysen  Urbana         Muy Alta
# 4         4    43   Masculino      O'Higgins  Urbana          Ninguna
# ...     ...   ...         ...            ...     ...              ...
# 1595   1595    27    Femenino  Metropolitana  Urbana             Alta
# 1596   1596    62    Femenino      Los Lagos   Rural            Media
# 1597   1597    60    Femenino       Los rios  Urbana             Alta
# 1598   1598    25    Femenino          Aysen  Urbana         Muy Alta
# 1599   1599    76   Masculino    Antofagasta  Urbana            Media
#
#      pensiones deportes_tipicos  voto
# 0      Estatal       Eliminarse     1
# 1      Estatal       Eliminarse     1
# 2      Estatal       Eliminarse     1
# 3      Estatal       Eliminarse     1
# 4        Mixto       Mantenerse     2
# ...        ...              ...   ...
# 1595     Mixto      Modificarse     1
# 1596     Mixto      Modificarse     2
# 1597     Mixto       Mantenerse     2
# 1598   Estatal      Modificarse     1
# 1599     Mixto       Mantenerse     2
#
# [1600 rows x 9 columns]

# %% [markdown]
# ### Obtener información con pandas

# %% [markdown]
# ####1) Tamaño del dataset

# %%
df.shape #filas, columnas
# Out:
# (1600, 9)

# %% [markdown]
# ####2) Nombres de columnas

# %%
df.columns
# Out:
# Index(['index', 'edad', 'genero', 'region', 'zona', 'cambio_climatico',
#        'pensiones', 'deportes_tipicos', 'voto'],
#       dtype='object')

# %% [markdown]
# ####3) Valores únicos en una columna

# %%
df['genero'].unique()
# Out:
# array(['Masculino', 'No Binario', 'Femenino'], dtype=object)

# %%
df['genero'].value_counts()
# Out:
# Femenino      745
# Masculino     703
# No Binario    152
# Name: genero, dtype: int64

# %% [markdown]
# ####4) Mínimo, máximo, media, mediana, cuartiles

# %%
df['edad'].min()
# Out:
# 18

# %%
df['edad'].max()
# Out:
# 80

# %%
df['edad'].mean()
# Out:
# 38.1525

# %%
df['edad'].median()
# Out:
# 35.0

# %%
df['edad'].quantile(q = 0.25)
# Out:
# 25.0

# %%
df['edad'].describe() #Solo funciona para columnas con valores numericos
# Out:
# count    1600.000000
# mean       38.152500
# std        15.370813
# min        18.000000
# 25%        25.000000
# 50%        35.000000
# 75%        49.000000
# max        80.000000
# Name: edad, dtype: float64

# %%
datos = df['edad'].describe()
datos['max']
# Out:
# 80.0

# %% [markdown]
# ####5) Filtrar datos

# %% [markdown]
# El método ``.loc`` selecciona las filas que cumplan con alguna condición lógica.

# %%
#Una sola condicion
df_tercera_edad = df.loc[df['edad'] >= 65]
df_tercera_edad
# Out:
#       index  edad     genero         region    zona cambio_climatico  \
# 41       41    76  Masculino  Metropolitana  Urbana             Baja
# 50       50    65  Masculino    Antofagasta  Urbana          Ninguna
# 53       53    68  Masculino          Maule  Urbana            Media
# 58       58    76   Femenino      Araucania   Rural            Media
# 66       66    78   Femenino        Atacama  Urbana          Ninguna
# ...     ...   ...        ...            ...     ...              ...
# 1473   1473    66  Masculino      Los Lagos  Urbana          Ninguna
# 1481   1481    80  Masculino          Arica   Rural            Media
# 1532   1532    65  Masculino       Coquimbo  Urbana            Media
# 1553   1553    75  Masculino    Antofagasta  Urbana            Media
# 1599   1599    76  Masculino    Antofagasta  Urbana            Media
#
#      pensiones deportes_tipicos  voto
# 41     Estatal       Mantenerse     1
# 50       Mixto       Mantenerse     2
# 53       Mixto       Mantenerse     2
# 58       Mixto      Modificarse     2
# 66       Mixto      Modificarse     2
# ...        ...              ...   ...
# 1473     Mixto       Mantenerse     2
# 1481     Mixto       Mantenerse     2
# 1532       AFP       Mantenerse     2
# 1553     Mixto       Mantenerse     2
# 1599     Mixto       Mantenerse     2
#
# [104 rows x 9 columns]

# %%
#Dos condiciones (AND)
df_tercera_edad_hombres = df.loc[ (df['edad'] >= 65) & (df['genero'] == 'Masculino')]
df_tercera_edad_hombres
# Out:
#       index  edad     genero         region    zona cambio_climatico  \
# 41       41    76  Masculino  Metropolitana  Urbana             Baja
# 50       50    65  Masculino    Antofagasta  Urbana          Ninguna
# 53       53    68  Masculino          Maule  Urbana            Media
# 84       84    68  Masculino      Los Lagos  Urbana          Ninguna
# 90       90    68  Masculino          Maule  Urbana            Media
# 123     123    75  Masculino       Coquimbo  Urbana             Baja
# 137     137    65  Masculino      Araucania   Rural            Media
# 143     143    77  Masculino       Coquimbo  Urbana         Muy Alta
# 156     156    80  Masculino          Arica  Urbana            Media
# 167     167    76  Masculino          Ñuble  Urbana            Media
# 199     199    76  Masculino  Metropolitana  Urbana             Baja
# 258     258    77  Masculino      Los Lagos   Rural             Baja
# 273     273    65  Masculino    Antofagasta  Urbana             Baja
# 302     302    75  Masculino          Ñuble   Rural         Muy Alta
# 335     335    66  Masculino          Maule   Rural             Baja
# 370     370    78  Masculino          Maule   Rural          Ninguna
# 374     374    77  Masculino          Maule   Rural            Media
# 522     522    79  Masculino       Coquimbo  Urbana             Baja
# 538     538    66  Masculino          Aysen   Rural            Media
# 598     598    70  Masculino    Antofagasta  Urbana             Baja
# 671     671    73  Masculino      O'Higgins  Urbana             Baja
# 687     687    71  Masculino          Aysen  Urbana            Media
# 691     691    80  Masculino          Ñuble  Urbana             Baja
# 829     829    74  Masculino        Atacama  Urbana            Media
# 938     938    76  Masculino      Araucania  Urbana            Media
# 948     948    65  Masculino      Los Lagos   Rural          Ninguna
# 1020   1020    70  Masculino    Antofagasta  Urbana            Media
# 1025   1025    70  Masculino        Bío Bio  Urbana          Ninguna
# 1033   1033    78  Masculino          Aysen  Urbana            Media
# 1039   1039    71  Masculino  Metropolitana   Rural            Media
# 1050   1050    76  Masculino     Valparaiso  Urbana         Muy Alta
# 1125   1125    77  Masculino          Maule  Urbana             Baja
# 1127   1127    69  Masculino      O'Higgins  Urbana             Alta
# 1128   1128    72  Masculino          Maule  Urbana             Baja
# 1207   1207    74  Masculino        Atacama  Urbana            Media
# 1280   1280    65  Masculino       Los rios  Urbana          Ninguna
# 1326   1326    65  Masculino      O'Higgins   Rural            Media
# 1340   1340    73  Masculino    Antofagasta  Urbana            Media
# 1367   1367    78  Masculino          Ñuble  Urbana             Baja
# 1418   1418    65  Masculino        Bío Bio  Urbana             Baja
# 1462   1462    71  Masculino       Coquimbo  Urbana          Ninguna
# 1469   1469    75  Masculino      Araucania  Urbana            Media
# 1473   1473    66  Masculino      Los Lagos  Urbana          Ninguna
# 1481   1481    80  Masculino          Arica   Rural            Media
# 1532   1532    65  Masculino       Coquimbo  Urbana            Media
# 1553   1553    75  Masculino    Antofagasta  Urbana            Media
# 1599   1599    76  Masculino    Antofagasta  Urbana            Media
#
#      pensiones deportes_tipicos  voto
# 41     Estatal       Mantenerse     1
# 50       Mixto       Mantenerse     2
# 53       Mixto       Mantenerse     2
# 84       Mixto       Mantenerse     2
# 90     Estatal      Modificarse     1
# 123      Mixto       Mantenerse     2
# 137      Mixto       Mantenerse     2
# 143      Mixto       Mantenerse     1
# 156      Mixto       Mantenerse     2
# 167      Mixto       Mantenerse     2
# 199    Estatal       Eliminarse     1
# 258        AFP       Mantenerse     2
# 273      Mixto       Mantenerse     2
# 302    Estatal       Eliminarse     1
# 335      Mixto       Mantenerse     2
# 370    Estatal       Mantenerse     2
# 374      Mixto       Mantenerse     2
# 522    Estatal       Mantenerse     1
# 538    Estatal       Mantenerse     1
# 598        AFP       Mantenerse     2
# 671      Mixto       Mantenerse     1
# 687      Mixto      Modificarse     1
# 691      Mixto       Mantenerse     2
# 829      Mixto       Mantenerse     2
# 938    Estatal       Mantenerse     2
# 948      Mixto       Mantenerse     2
# 1020     Mixto       Mantenerse     2
# 1025     Mixto       Mantenerse     2
# 1033     Mixto       Mantenerse     2
# 1039   Estatal      Modificarse     1
# 1050   Estatal       Mantenerse     1
# 1125       AFP       Mantenerse     2
# 1127   Estatal       Mantenerse     1
# 1128     Mixto       Mantenerse     2
# 1207   Estatal      Modificarse     1
# 1280     Mixto       Mantenerse     2
# 1326   Estatal       Mantenerse     1
# 1340     Mixto      Modificarse     1
# 1367   Estatal      Modificarse     1
# 1418       AFP       Mantenerse     2
# 1462     Mixto       Mantenerse     2
# 1469     Mixto       Mantenerse     2
# 1473     Mixto       Mantenerse     2
# 1481     Mixto       Mantenerse     2
# 1532       AFP       Mantenerse     2
# 1553     Mixto       Mantenerse     2
# 1599     Mixto       Mantenerse     2

# %%
#Una u otra condicion (OR)
df_tercera_edad_hombres = df.loc[ (df['region'] == 'Atacama') | (df['region'] == 'Los Lagos')]
df_tercera_edad_hombres
# Out:
#       index  edad      genero     region    zona cambio_climatico pensiones  \
# 7         7    25   Masculino    Atacama  Urbana             Alta       AFP
# 44       44    49   Masculino    Atacama  Urbana            Media     Mixto
# 65       65    45   Masculino  Los Lagos   Rural          Ninguna       AFP
# 66       66    78    Femenino    Atacama  Urbana          Ninguna     Mixto
# 77       77    37  No Binario  Los Lagos  Urbana             Alta     Mixto
# ...     ...   ...         ...        ...     ...              ...       ...
# 1563   1563    27    Femenino  Los Lagos  Urbana         Muy Alta       AFP
# 1572   1572    26  No Binario    Atacama  Urbana             Alta   Estatal
# 1576   1576    39   Masculino  Los Lagos  Urbana             Baja     Mixto
# 1580   1580    21    Femenino    Atacama  Urbana         Muy Alta       AFP
# 1596   1596    62    Femenino  Los Lagos   Rural            Media     Mixto
#
#      deportes_tipicos  voto
# 7          Mantenerse     2
# 44        Modificarse     2
# 65         Mantenerse     2
# 66        Modificarse     2
# 77         Eliminarse     1
# ...               ...   ...
# 1563       Mantenerse     2
# 1572      Modificarse     1
# 1576       Mantenerse     2
# 1580       Eliminarse     2
# 1596      Modificarse     2
#
# [200 rows x 9 columns]

# %% [markdown]
# **Observación:**
#
# * Para evaluar 2 o más condiciones, cada condición deber ir entre parentesis ().
# * Las condiciones **si distinguen mayúsculas** en los nombres de columnas y valores filtrados. Es decir, no es lo mismo escribir 'Edad' y 'edad' al acceder a una columna, tampoco es lo mismo escribir 'Masculino' y 'masculino' al querer acceder solo a dicho género.
# * Para recordar los nombres de columnas podría resultar útil crear un nuevo bloque de código y ejecutar ``df.columns``
# * Para recordar los posibles valores que puede tomar una columa podría ser útil crear un nuevo bloque de código y ejecutar ``df['ColumnaDeInteres].unique()``

# %% [markdown]
# ####6) Crear sub-dataframe con algunas columnas

# %%
#Crear nuevo dataframe solo con las columnas 'edad' y 'genero'
df_nuevo = df[['edad', 'genero']]
df_nuevo
# Out:
#       edad      genero
# 0       21   Masculino
# 1       61   Masculino
# 2       22  No Binario
# 3       21   Masculino
# 4       43   Masculino
# ...    ...         ...
# 1595    27    Femenino
# 1596    62    Femenino
# 1597    60    Femenino
# 1598    25    Femenino
# 1599    76   Masculino
#
# [1600 rows x 2 columns]

# %%
#Crear nuevo dataframe con los registros que cumplan alguna condición y solo con las columnas 'edad' y 'genero'
df_nuevo2 = df.loc[ df['edad'] >= 65 , ['edad', 'genero']]
df_nuevo2
# Out:
#       edad     genero
# 41      76  Masculino
# 50      65  Masculino
# 53      68  Masculino
# 58      76   Femenino
# 66      78   Femenino
# ...    ...        ...
# 1473    66  Masculino
# 1481    80  Masculino
# 1532    65  Masculino
# 1553    75  Masculino
# 1599    76  Masculino
#
# [104 rows x 2 columns]

# %% [markdown]
# ### Gráficos

# %% [markdown]
# En general, se utiliza la librería **pandas** para filtrar datos y la libería **matplotlib** para graficarlos. Además, existe la librería **seaborn**, la cual se utiliza para crear gráficos estadísticos atractivos y fáciles de interpretar.
#
# Se recomienda que investiguen sobre cómo graficar utilizando **seaborn**, ya que les podría resultar mucho más simple. Algunas funciones de interés podrían ser:
#
# * seaborn.countplot()
# * seaborn.boxplot()
# * seaborn.histplot()

# %% [markdown]
# #### Barras

# %%
#Grafico de frecuencias de cada genero

#Se obtienen las frecuencias de cada genero
frecuencias = df['genero'].value_counts()

#Se realiza un grafico (plot) de tipo barras (kind = 'bar')
frecuencias.plot(kind = 'bar')

#nombres de los ejes
plt.xlabel('genero')
plt.ylabel('frecuencia')
plt.show()

# %% [markdown]
# #### Histograma

# %%
df['edad'].hist(bins = 10)  #se puede cambiar la cantidad de barras pasando el parametro bins

plt.title('Histograma de edad')
plt.xlabel('edad')
plt.ylabel('frecuencia')

plt.show()

# %% [markdown]
# #### Boxplot

# %%
masculino  = df.loc[df['genero'] == 'Masculino']['edad']
femenino   = df.loc[df['genero'] == 'Femenino']['edad']
no_binario = df.loc[df['genero'] == 'No Binario']['edad']

plt.boxplot([masculino, femenino, no_binario])

plt.xlabel('genero')
plt.ylabel('edad')
plt.xticks([1, 2, 3], ['Masculino', 'Femenino', 'No Binario'])
plt.show()
